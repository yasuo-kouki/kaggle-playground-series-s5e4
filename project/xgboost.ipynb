# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import shap

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
import xgboost as xgb

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

import optuna
import os
from scipy import stats

import joblib

# %%
train = pd.read_csv("../data/train.csv")
predict = pd.read_csv("../data/test.csv")

# %% [markdown]
# # データの前処理

# %% [markdown]
# ### Object型のデータのラベル付け

# %%
# Label Encoding

def label_encode(df, columns):
    le = LabelEncoder()

    for col in columns:
        df[col] = le.fit_transform(df[col])
    return df

encode_columns = ['road_type','lighting','weather','time_of_day']
train = label_encode(train, encode_columns)
predict = label_encode(predict, encode_columns)

# %%
# bool型の変換

def bool_to_int(df):
    bool_columns = df.select_dtypes(include='bool').columns
    for col in bool_columns:
        df[col] = df[col].astype(int)
    return df

train = bool_to_int(train)
predict = bool_to_int(predict)

# %%
train.head()
# Out:
#    id  road_type  num_lanes  curvature  speed_limit  lighting  weather  \
# 0   0          2          2       0.06           35         0        2
# 1   1          2          4       0.99           35         0        0
# 2   2          1          4       0.63           70         1        0
# 3   3          0          4       0.07           35         1        2
# 4   4          1          1       0.58           60         0        1
#
#    road_signs_present  public_road  time_of_day  holiday  school_season  \
# 0                   0            1            0        0              1
# 1                   1            0            1        1              1
# 2                   0            1            2        1              0
# 3                   1            1            2        0              0
# 4                   0            0            1        1              0
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %% [markdown]
# ## 特徴量の作成

# %%
def create_features(df):
    # カーブと報告事故件数
    df['curavture_accidents'] = df['curvature'] * df['num_reported_accidents']

    return df

train = create_features(train)
predict = create_features(predict)

# %% [markdown]
# ### スケーリング

# %%
# 残留誤差が大きいため，異常値に強いRobustScalerを使用
def robust_scale(df):
    scaler = RobustScaler()

    numeric_columns = ['curvature','curavture_accidents']

    df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
    return df

train = robust_scale(train)
predict = robust_scale(predict)

# %% [markdown]
# ### データ分割

# %%
def split_data(df,test_size=0.2,random_state=42):
    X = df.drop(columns=['id','accident_risk'])
    y = df['accident_risk']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_data(train)

predict_X = predict.copy()
predict_X = predict_X.drop(columns=['id'])

# %% [markdown]
# # モデルの学習

# %%
# XGBoostモデルの構築
def build_xgboost_model(n_estimators=100,max_depth=5,learning_rate=0.1,radom_state=42):
    model = xgb.XGBRegressor(
        # 回帰タスクに適した損失関数(RMSE)
        obextive = 'reg:squarederror',
        # 決定機の数
        n_estimators = n_estimators,
        # 決定木の深さ
        max_depth = max_depth,
        # 学習率
        learning_rate = learning_rate,
        # 乱数シード
        random_state = radom_state
    )
    return model

# モデルの構築
xgb_model = build_xgboost_model()

# %%
# 特徴量のプロット

xgb_model.fit(X_train, y_train)

xgb.plot_importance(xgb_model)
plt.title('Feature_Importance')
plt.show()
# Out:
# /Users/yasuo/myenv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [09:52:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "obextive" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
def explain_model(model):
    explainer = shap.Explainer(model)
    shap_values = explainer(X_test)
    
    shap.plots.waterfall(shap_values[0])

    shap.plots.beeswarm(shap_values)

explain_model(xgb_model)

# %% [markdown]
# # モデルの評価

# %%
# テストデータの予測
xgb_pred = xgb_model.predict(X_test)

# %%
def evalute_metrics(y_true,y_pred):
    results = []

    def calulate_metrics(y_true,y_pred):
        mse = mean_squared_error(y_true,y_pred)
        mae = mean_absolute_error(y_true,y_pred)
        r2 = r2_score(y_true,y_pred)
        return {
            'MSE':mse,
            'MAE':mae,
            'R2':r2
        }

    results.append(calulate_metrics(y_true,y_pred))
    
    return pd.DataFrame(results)

# 評価指標の計算
results = evalute_metrics(y_test,xgb_pred)
display(results)
# Out:
#         MSE       MAE        R2
# 0  0.003186  0.043832  0.884623

# %% [markdown]
# # 最適化学習

# %%
"""
def optimize_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500), # 決定木の数
        'max_depth': trial.suggest_int('max_depth', 3, 10), # 決定木の深さ
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3), # 学習率
        'subsample': trial.suggest_float('subsample', 0.6, 1.0), # サブサンプル
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0), # 列のサブサンプル
        'gamma': trial.suggest_float('gamma', 0, 1), # 葉ノードを分割するために必要な最小損失削減
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # 葉ノードの重みの最小合計
        'objective': 'reg:squarederror', # 回帰タスクに適した損失関数
        'random_state': 42                
    }

    model = xgb.XGBRegressor(**params)
    model = model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)

    return mse

study = optuna.create_study(direction='minimize')
study.optimize(optimize_xgboost, n_trials=50)

# dislay best results
print('Best trial:')
trial = study.best_trial # 最良のトライアル
print(f"  MSE: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Predict
optimized_xgb = xgb.XGBRegressor(**trial.params, random_state=42)
optimized_xgb.fit(X_train, y_train)
#"""
# Out:
# '\ndef optimize_xgboost(trial):\n    params = {\n        \'n_estimators\': trial.suggest_int(\'n_estimators\', 50, 500), # 決定木の数\n        \'max_depth\': trial.suggest_int(\'max_depth\', 3, 10), # 決定木の深さ\n        \'learning_rate\': trial.suggest_float(\'learning_rate\', 0.01, 0.3), # 学習率\n        \'subsample\': trial.suggest_float(\'subsample\', 0.6, 1.0), # サブサンプル\n        \'colsample_bytree\': trial.suggest_float(\'colsample_bytree\', 0.6, 1.0), # 列のサブサンプル\n        \'gamma\': trial.suggest_float(\'gamma\', 0, 1), # 葉ノードを分割するために必要な最小損失削減\n        \'min_child_weight\': trial.suggest_int(\'min_child_weight\', 1, 10), # 葉ノードの重みの最小合計\n        \'objective\': \'reg:squarederror\', # 回帰タスクに適した損失関数\n        \'random_state\': 42                \n    }\n\n    model = xgb.XGBRegressor(**params)\n    model = model.fit(X_train, y_train)\n\n    y_pred = model.predict(X_test)\n    mse = mean_squared_error(y_test, y_pred)\n\n    return mse\n\nstudy = optuna.create_study(direction=\'minimize\')\nstudy.optimize(optimize_xgboost, n_trials=50)\n\n# dislay best results\nprint(\'Best trial:\')\ntrial = study.best_trial # 最良のトライアル\nprint(f"  MSE: {trial.value}")\nprint("  Params: ")\nfor key, value in trial.params.items():\n    print(f"    {key}: {value}")\n\n# Predict\noptimized_xgb = xgb.XGBRegressor(**trial.params, random_state=42)\noptimized_xgb.fit(X_train, y_train)\n#'

# %%
#"""
def optimize_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500), # 決定木の数
        'max_depth': trial.suggest_int('max_depth', 3, 15), # 決定木の深さ
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3), # 学習率
        'subsample': trial.suggest_float('subsample', 0.6, 1.0), # サブサンプル
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0), # 列のサブサンプル
        'gamma': trial.suggest_float('gamma', 0, 0.5), # 葉ノードを分割するために必要な最小損失削減
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # 葉ノードの重みの最小合計
        'objective': 'reg:pseudohubererror',
        'random_state': 42                
    }

    model = xgb.XGBRegressor(**params)
    model = model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)

    return mse

study = optuna.create_study(direction='minimize')
study.optimize(optimize_xgboost, n_trials=100)

# dislay best results
print('Best trial:')
trial = study.best_trial # 最良のトライアル
print(f"  MSE: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Predict
optimized_xgb = xgb.XGBRegressor(**trial.params, random_state=42)
optimized_xgb.fit(X_train, y_train)
#"""
# Out:
# [I 2025-10-17 09:52:27,872] A new study created in memory with name: no-name-c03c2b13-39cf-433e-a1b7-27da886f863e
# [I 2025-10-17 09:52:28,743] Trial 0 finished with value: 0.003193469524264717 and parameters: {'n_estimators': 134, 'max_depth': 7, 'learning_rate': 0.03338463083599916, 'subsample': 0.8538217312703029, 'colsample_bytree': 0.8951533261707337, 'gamma': 0.07993914830945553, 'min_child_weight': 9}. Best is trial 0 with value: 0.003193469524264717.
# [I 2025-10-17 09:52:28,987] Trial 1 finished with value: 0.003252233751223838 and parameters: {'n_estimators': 63, 'max_depth': 4, 'learning_rate': 0.1627352665287361, 'subsample': 0.8904040913752918, 'colsample_bytree': 0.8569385256431074, 'gamma': 0.34707247815140646, 'min_child_weight': 3}. Best is trial 0 with value: 0.003193469524264717.
# [I 2025-10-17 09:52:29,732] Trial 2 finished with value: 0.0032020419344880526 and parameters: {'n_estimators': 301, 'max_depth': 15, 'learning_rate': 0.14963777227066638, 'subsample': 0.607621800102, 'colsample_bytree': 0.6801651883783925, 'gamma': 0.12732540217437238, 'min_child_weight': 10}. Best is trial 0 with value: 0.003193469524264717.
# [I 2025-10-17 09:52:30,436] Trial 3 finished with value: 0.0032142577993996323 and parameters: {'n_estimators': 332, 'max_depth': 15, 'learning_rate': 0.14410950208282589, 'subsample': 0.9598868311314797, 'colsample_bytree': 0.8837592251393198, 'gamma': 0.45025185930992556, 'min_child_weight': 6}. Best is trial 0 with value: 0.003193469524264717.
# [I 2025-10-17 09:52:30,690] Trial 4 finished with value: 0.003388070434634377 and parameters: {'n_estimators': 59, 'max_depth': 3, 'learning_rate': 0.09638010879812813, 'subsample': 0.7048742689407567, 'colsample_bytree': 0.6167652784589122, 'gamma': 0.4646940431919776, 'min_child_weight': 5}. Best is trial 0 with value: 0.003193469524264717.
# [I 2025-10-17 09:52:31,262] Trial 5 finished with value: 0.0031632067504138144 and parameters: {'n_estimators': 237, 'max_depth': 7, 'learning_rate': 0.21599697999008874, 'subsample': 0.7945718281807883, 'colsample_bytree': 0.9272802419881738, 'gamma': 0.02758208192390199, 'min_child_weight': 1}. Best is trial 5 with value: 0.0031632067504138144.
# [I 2025-10-17 09:52:31,627] Trial 6 finished with value: 0.0032210146537208885 and parameters: {'n_estimators': 82, 'max_depth': 8, 'learning_rate': 0.1150715672355526, 'subsample': 0.7569609075538637, 'colsample_bytree': 0.7120511679563135, 'gamma': 0.4279570131068528, 'min_child_weight': 1}. Best is trial 5 with value: 0.0031632067504138144.
# [I 2025-10-17 09:52:32,430] Trial 7 finished with value: 0.0032323048903747913 and parameters: {'n_estimators': 398, 'max_depth': 5, 'learning_rate': 0.16335805796082498, 'subsample': 0.601609120956348, 'colsample_bytree': 0.9343869974706556, 'gamma': 0.3415847316750599, 'min_child_weight': 5}. Best is trial 5 with value: 0.0031632067504138144.
# [I 2025-10-17 09:52:32,945] Trial 8 finished with value: 0.003245137716812378 and parameters: {'n_estimators': 70, 'max_depth': 11, 'learning_rate': 0.04650510759641474, 'subsample': 0.8128527379196137, 'colsample_bytree': 0.9868113731777013, 'gamma': 0.23087447704090813, 'min_child_weight': 4}. Best is trial 5 with value: 0.0031632067504138144.
# [I 2025-10-17 09:52:33,689] Trial 9 finished with value: 0.003310056866741833 and parameters: {'n_estimators': 383, 'max_depth': 3, 'learning_rate': 0.18275206178894876, 'subsample': 0.6512819167327057, 'colsample_bytree': 0.7631557076030864, 'gamma': 0.4585000388085319, 'min_child_weight': 3}. Best is trial 5 with value: 0.0031632067504138144.
# [I 2025-10-17 09:52:34,220] Trial 10 finished with value: 0.0031567991926493193 and parameters: {'n_estimators': 208, 'max_depth': 11, 'learning_rate': 0.2639385106539489, 'subsample': 0.9850013069609983, 'colsample_bytree': 0.992467907592115, 'gamma': 0.017885334213972648, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:34,721] Trial 11 finished with value: 0.00315755046254945 and parameters: {'n_estimators': 210, 'max_depth': 11, 'learning_rate': 0.2700085777535476, 'subsample': 0.9866480248580474, 'colsample_bytree': 0.9884055334430861, 'gamma': 0.01952474828535026, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:35,151] Trial 12 finished with value: 0.00318314262266563 and parameters: {'n_estimators': 208, 'max_depth': 11, 'learning_rate': 0.2970869237089783, 'subsample': 0.9990770470290425, 'colsample_bytree': 0.9918870960412294, 'gamma': 0.15039331433252753, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:35,675] Trial 13 finished with value: 0.0031757471232496367 and parameters: {'n_estimators': 179, 'max_depth': 11, 'learning_rate': 0.2867243810343602, 'subsample': 0.9236650960171313, 'colsample_bytree': 0.8049000369321427, 'gamma': 0.006943994242451533, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:36,470] Trial 14 finished with value: 0.0031855664723265246 and parameters: {'n_estimators': 474, 'max_depth': 13, 'learning_rate': 0.24707146870379768, 'subsample': 0.9955594322656931, 'colsample_bytree': 0.9912010110502866, 'gamma': 0.19554668791856797, 'min_child_weight': 7}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:36,885] Trial 15 finished with value: 0.003174821214930322 and parameters: {'n_estimators': 154, 'max_depth': 10, 'learning_rate': 0.2453714531571871, 'subsample': 0.9217633327751245, 'colsample_bytree': 0.8284563719743454, 'gamma': 0.08156728921100925, 'min_child_weight': 3}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:37,485] Trial 16 finished with value: 0.0031663479723320585 and parameters: {'n_estimators': 259, 'max_depth': 13, 'learning_rate': 0.24500287894131811, 'subsample': 0.8662149428136912, 'colsample_bytree': 0.9387482064220312, 'gamma': 0.06088362092137943, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:37,861] Trial 17 finished with value: 0.0031810050384782356 and parameters: {'n_estimators': 125, 'max_depth': 13, 'learning_rate': 0.20359197497611342, 'subsample': 0.9427296171851096, 'colsample_bytree': 0.9542650693507486, 'gamma': 0.14799704108792994, 'min_child_weight': 7}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:38,347] Trial 18 finished with value: 0.0032097140884553513 and parameters: {'n_estimators': 217, 'max_depth': 9, 'learning_rate': 0.2700213531488025, 'subsample': 0.9672275151505474, 'colsample_bytree': 0.7487990241132443, 'gamma': 0.29846741195029214, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:39,018] Trial 19 finished with value: 0.0031661208683274643 and parameters: {'n_estimators': 287, 'max_depth': 12, 'learning_rate': 0.2039319116598351, 'subsample': 0.888127135129601, 'colsample_bytree': 0.8871416652462647, 'gamma': 0.0420016085639886, 'min_child_weight': 4}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:39,724] Trial 20 finished with value: 0.0031803417183668037 and parameters: {'n_estimators': 347, 'max_depth': 9, 'learning_rate': 0.272443277799349, 'subsample': 0.8187159792133669, 'colsample_bytree': 0.9596446861939241, 'gamma': 0.11565108180713202, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:40,793] Trial 21 finished with value: 0.0031721662423769637 and parameters: {'n_estimators': 238, 'max_depth': 6, 'learning_rate': 0.22125851410807765, 'subsample': 0.7626781962633038, 'colsample_bytree': 0.9101951657364687, 'gamma': 0.003999385947996335, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:41,253] Trial 22 finished with value: 0.003165444675990212 and parameters: {'n_estimators': 174, 'max_depth': 7, 'learning_rate': 0.22978232352783456, 'subsample': 0.7779594971261894, 'colsample_bytree': 0.9971348321342222, 'gamma': 0.03332389800937868, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:41,736] Trial 23 finished with value: 0.0031924535499960357 and parameters: {'n_estimators': 210, 'max_depth': 8, 'learning_rate': 0.2645949310966281, 'subsample': 0.7085197718504936, 'colsample_bytree': 0.9267838045770371, 'gamma': 0.18860685203030925, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:42,286] Trial 24 finished with value: 0.003175942637034359 and parameters: {'n_estimators': 266, 'max_depth': 10, 'learning_rate': 0.29952609643617994, 'subsample': 0.8397674474408394, 'colsample_bytree': 0.9600309634727977, 'gamma': 0.10133878776467148, 'min_child_weight': 3}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:42,688] Trial 25 finished with value: 0.0031667101050862154 and parameters: {'n_estimators': 107, 'max_depth': 10, 'learning_rate': 0.20975353715443895, 'subsample': 0.7086833378759344, 'colsample_bytree': 0.8474036504188991, 'gamma': 0.03910416891397099, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:43,250] Trial 26 finished with value: 0.0031776175775980564 and parameters: {'n_estimators': 182, 'max_depth': 12, 'learning_rate': 0.2545058647045739, 'subsample': 0.9053144635922864, 'colsample_bytree': 0.958617845935367, 'gamma': 0.008403722994520378, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:43,796] Trial 27 finished with value: 0.0031741774537042797 and parameters: {'n_estimators': 234, 'max_depth': 8, 'learning_rate': 0.18837271482927867, 'subsample': 0.9584970861918763, 'colsample_bytree': 0.865033282079535, 'gamma': 0.06978827471767174, 'min_child_weight': 4}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:44,421] Trial 28 finished with value: 0.0032093493479510697 and parameters: {'n_estimators': 307, 'max_depth': 6, 'learning_rate': 0.22497908768149943, 'subsample': 0.7921174252044362, 'colsample_bytree': 0.9189522564943164, 'gamma': 0.17753300650990758, 'min_child_weight': 8}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:44,791] Trial 29 finished with value: 0.003183155325674799 and parameters: {'n_estimators': 140, 'max_depth': 7, 'learning_rate': 0.28027411874149627, 'subsample': 0.8565351090123744, 'colsample_bytree': 0.8980125451450184, 'gamma': 0.09207067642796443, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:45,339] Trial 30 finished with value: 0.003197178640653565 and parameters: {'n_estimators': 246, 'max_depth': 12, 'learning_rate': 0.23356182198656736, 'subsample': 0.739683133285557, 'colsample_bytree': 0.9661946087368588, 'gamma': 0.2527816864355207, 'min_child_weight': 10}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:45,795] Trial 31 finished with value: 0.0031708580719300517 and parameters: {'n_estimators': 175, 'max_depth': 7, 'learning_rate': 0.22649525438640167, 'subsample': 0.7890877509912207, 'colsample_bytree': 0.9986297257578807, 'gamma': 0.04768511655324438, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:46,261] Trial 32 finished with value: 0.003183557512568637 and parameters: {'n_estimators': 196, 'max_depth': 6, 'learning_rate': 0.2613456182910649, 'subsample': 0.8338070151481343, 'colsample_bytree': 0.9764697769036619, 'gamma': 0.04175673162212286, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:47,023] Trial 33 finished with value: 0.00317814567832019 and parameters: {'n_estimators': 165, 'max_depth': 5, 'learning_rate': 0.17295244213259103, 'subsample': 0.776849465934081, 'colsample_bytree': 0.9993291269173226, 'gamma': 0.00012037036817501637, 'min_child_weight': 3}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:47,921] Trial 34 finished with value: 0.0039214151116650905 and parameters: {'n_estimators': 112, 'max_depth': 8, 'learning_rate': 0.016119769898606584, 'subsample': 0.7423790730177525, 'colsample_bytree': 0.9405623676914445, 'gamma': 0.030408565118713496, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:48,590] Trial 35 finished with value: 0.0031787388467537014 and parameters: {'n_estimators': 284, 'max_depth': 14, 'learning_rate': 0.13632851676131674, 'subsample': 0.8729450599099146, 'colsample_bytree': 0.9732951900605986, 'gamma': 0.128631757967763, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:49,016] Trial 36 finished with value: 0.0032206479361401377 and parameters: {'n_estimators': 147, 'max_depth': 5, 'learning_rate': 0.236825468547232, 'subsample': 0.6828109452951736, 'colsample_bytree': 0.6149627334705737, 'gamma': 0.08965783440145131, 'min_child_weight': 2}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:49,634] Trial 37 finished with value: 0.0032075167587300884 and parameters: {'n_estimators': 319, 'max_depth': 9, 'learning_rate': 0.18940341008191958, 'subsample': 0.9805986868208822, 'colsample_bytree': 0.8789990577297306, 'gamma': 0.3950996841302692, 'min_child_weight': 3}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:50,201] Trial 38 finished with value: 0.003168966879366125 and parameters: {'n_estimators': 223, 'max_depth': 7, 'learning_rate': 0.21231758699031766, 'subsample': 0.8101413304635927, 'colsample_bytree': 0.9075072388834506, 'gamma': 0.02921478880603614, 'min_child_weight': 4}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:50,497] Trial 39 finished with value: 0.0032311658936278053 and parameters: {'n_estimators': 93, 'max_depth': 4, 'learning_rate': 0.2830501687405844, 'subsample': 0.6300867783078652, 'colsample_bytree': 0.9412921668707254, 'gamma': 0.06687131485205151, 'min_child_weight': 1}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:51,106] Trial 40 finished with value: 0.0031885909237344165 and parameters: {'n_estimators': 197, 'max_depth': 10, 'learning_rate': 0.1171847233167472, 'subsample': 0.9435341082196131, 'colsample_bytree': 0.6542102273649858, 'gamma': 0.12477891071971342, 'min_child_weight': 5}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:51,685] Trial 41 finished with value: 0.003221121878419212 and parameters: {'n_estimators': 286, 'max_depth': 12, 'learning_rate': 0.20243148898972946, 'subsample': 0.8864183899207532, 'colsample_bytree': 0.8833599812101315, 'gamma': 0.4994179771031224, 'min_child_weight': 4}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:52,397] Trial 42 finished with value: 0.003158939550838604 and parameters: {'n_estimators': 352, 'max_depth': 11, 'learning_rate': 0.2543978930543636, 'subsample': 0.9106864071283828, 'colsample_bytree': 0.9758378051994518, 'gamma': 0.028983530879688982, 'min_child_weight': 6}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:53,090] Trial 43 finished with value: 0.0031584791122649925 and parameters: {'n_estimators': 353, 'max_depth': 11, 'learning_rate': 0.25650772361802365, 'subsample': 0.9805294000504468, 'colsample_bytree': 0.9782259480960175, 'gamma': 0.02755562543109288, 'min_child_weight': 6}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:53,806] Trial 44 finished with value: 0.0031570098043189193 and parameters: {'n_estimators': 364, 'max_depth': 11, 'learning_rate': 0.25590969959284826, 'subsample': 0.9800698390186786, 'colsample_bytree': 0.9768762540169638, 'gamma': 0.02181361528202333, 'min_child_weight': 6}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:54,826] Trial 45 finished with value: 0.0031651588356744484 and parameters: {'n_estimators': 404, 'max_depth': 11, 'learning_rate': 0.07533475081848345, 'subsample': 0.9723437658408103, 'colsample_bytree': 0.9768544189405646, 'gamma': 0.06424625161817281, 'min_child_weight': 6}. Best is trial 10 with value: 0.0031567991926493193.
# [I 2025-10-17 09:52:55,567] Trial 46 finished with value: 0.003156759716731463 and parameters: {'n_estimators': 369, 'max_depth': 11, 'learning_rate': 0.2539938154865846, 'subsample': 0.9423724513772035, 'colsample_bytree': 0.9780231035319196, 'gamma': 0.019581891413835772, 'min_child_weight': 7}. Best is trial 46 with value: 0.003156759716731463.
# [I 2025-10-17 09:52:56,384] Trial 47 finished with value: 0.003164207474886272 and parameters: {'n_estimators': 426, 'max_depth': 14, 'learning_rate': 0.2923930302719743, 'subsample': 0.9869843658617328, 'colsample_bytree': 0.9480921551075612, 'gamma': 0.01272627721594781, 'min_child_weight': 7}. Best is trial 46 with value: 0.003156759716731463.
# [I 2025-10-17 09:52:57,172] Trial 48 finished with value: 0.0031672262471580856 and parameters: {'n_estimators': 438, 'max_depth': 11, 'learning_rate': 0.2765735027487447, 'subsample': 0.9420285649348555, 'colsample_bytree': 0.9269631116360876, 'gamma': 0.057347153393114705, 'min_child_weight': 9}. Best is trial 46 with value: 0.003156759716731463.
# [I 2025-10-17 09:52:57,855] Trial 49 finished with value: 0.003174939990052109 and parameters: {'n_estimators': 364, 'max_depth': 13, 'learning_rate': 0.24227503079918283, 'subsample': 0.9549695735340012, 'colsample_bytree': 0.9825963251180296, 'gamma': 0.1043622336523954, 'min_child_weight': 8}. Best is trial 46 with value: 0.003156759716731463.
# [I 2025-10-17 09:52:58,537] Trial 50 finished with value: 0.0032040552735054383 and parameters: {'n_estimators': 382, 'max_depth': 10, 'learning_rate': 0.25628903315905127, 'subsample': 0.9845974140995593, 'colsample_bytree': 0.767420692483451, 'gamma': 0.22772016372223655, 'min_child_weight': 7}. Best is trial 46 with value: 0.003156759716731463.
# [I 2025-10-17 09:52:59,254] Trial 51 finished with value: 0.003156122710581221 and parameters: {'n_estimators': 345, 'max_depth': 11, 'learning_rate': 0.2538867213777776, 'subsample': 0.9183489536942057, 'colsample_bytree': 0.9802108693203373, 'gamma': 0.021364535135817236, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:52:59,951] Trial 52 finished with value: 0.003156460344947578 and parameters: {'n_estimators': 330, 'max_depth': 12, 'learning_rate': 0.2643525039349539, 'subsample': 0.9293961295457355, 'colsample_bytree': 0.9509863149054507, 'gamma': 0.01742289728581109, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:00,584] Trial 53 finished with value: 0.0031705298601743797 and parameters: {'n_estimators': 325, 'max_depth': 12, 'learning_rate': 0.269899264918856, 'subsample': 0.9298366864275996, 'colsample_bytree': 0.9507259940250706, 'gamma': 0.07971294519278295, 'min_child_weight': 5}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:01,372] Trial 54 finished with value: 0.003163741426907928 and parameters: {'n_estimators': 371, 'max_depth': 14, 'learning_rate': 0.2877395649291206, 'subsample': 0.903229597886139, 'colsample_bytree': 0.9857616283964197, 'gamma': 0.01263393239791278, 'min_child_weight': 8}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:01,979] Trial 55 finished with value: 0.003165161249501044 and parameters: {'n_estimators': 309, 'max_depth': 12, 'learning_rate': 0.24903319620070555, 'subsample': 0.9993015037923775, 'colsample_bytree': 0.9650254153763467, 'gamma': 0.05943813829865974, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:02,718] Trial 56 finished with value: 0.0031935475723658124 and parameters: {'n_estimators': 405, 'max_depth': 13, 'learning_rate': 0.2699641403615666, 'subsample': 0.9299632648731031, 'colsample_bytree': 0.7118692851581779, 'gamma': 0.14530876427959583, 'min_child_weight': 7}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:03,594] Trial 57 finished with value: 0.0031570025310395733 and parameters: {'n_estimators': 463, 'max_depth': 9, 'learning_rate': 0.2426282702709864, 'subsample': 0.9534195281582937, 'colsample_bytree': 0.934504198877725, 'gamma': 0.014111844521699994, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:04,441] Trial 58 finished with value: 0.003169482460797331 and parameters: {'n_estimators': 462, 'max_depth': 9, 'learning_rate': 0.2379800229918263, 'subsample': 0.9507185523471341, 'colsample_bytree': 0.916843535202416, 'gamma': 0.051202959557641, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:07,657] Trial 59 finished with value: 0.0034382761533504704 and parameters: {'n_estimators': 437, 'max_depth': 10, 'learning_rate': 0.21979767492874352, 'subsample': 0.9652822708518435, 'colsample_bytree': 0.9347393484608552, 'gamma': 0.00041738037705521536, 'min_child_weight': 5}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:08,286] Trial 60 finished with value: 0.003207447470350575 and parameters: {'n_estimators': 336, 'max_depth': 9, 'learning_rate': 0.2621257864412829, 'subsample': 0.9155065952350856, 'colsample_bytree': 0.8378333195845067, 'gamma': 0.3607505341569247, 'min_child_weight': 7}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:09,034] Trial 61 finished with value: 0.003157217024448653 and parameters: {'n_estimators': 392, 'max_depth': 11, 'learning_rate': 0.28276357635772753, 'subsample': 0.9695107279307678, 'colsample_bytree': 0.9569627683062619, 'gamma': 0.021216938666771358, 'min_child_weight': 5}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:09,791] Trial 62 finished with value: 0.0031566400530651326 and parameters: {'n_estimators': 388, 'max_depth': 10, 'learning_rate': 0.2816969240595787, 'subsample': 0.935679401658312, 'colsample_bytree': 0.9555212277878606, 'gamma': 0.019085824924000606, 'min_child_weight': 5}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:10,537] Trial 63 finished with value: 0.0031698526894333645 and parameters: {'n_estimators': 414, 'max_depth': 10, 'learning_rate': 0.29259616065801786, 'subsample': 0.9386967344124603, 'colsample_bytree': 0.9490182463966259, 'gamma': 0.07745460080031168, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:11,276] Trial 64 finished with value: 0.0031663374225350707 and parameters: {'n_estimators': 378, 'max_depth': 10, 'learning_rate': 0.24813724706629664, 'subsample': 0.9236102460975892, 'colsample_bytree': 0.898080986181632, 'gamma': 0.04135035463684779, 'min_child_weight': 6}. Best is trial 51 with value: 0.003156122710581221.
# [I 2025-10-17 09:53:12,150] Trial 65 finished with value: 0.0031559753141934023 and parameters: {'n_estimators': 455, 'max_depth': 12, 'learning_rate': 0.27448879288463035, 'subsample': 0.8956466859709958, 'colsample_bytree': 0.965536306530316, 'gamma': 0.02043688896183698, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:17,694] Trial 66 finished with value: 0.004025512901687833 and parameters: {'n_estimators': 488, 'max_depth': 12, 'learning_rate': 0.2984831185058501, 'subsample': 0.9006066561030653, 'colsample_bytree': 0.8131954089806881, 'gamma': 0.00038651157752125215, 'min_child_weight': 8}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:18,534] Trial 67 finished with value: 0.0031654797592462975 and parameters: {'n_estimators': 450, 'max_depth': 13, 'learning_rate': 0.2757947978026215, 'subsample': 0.8832968529318355, 'colsample_bytree': 0.9293110353354735, 'gamma': 0.0499928359283037, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:19,406] Trial 68 finished with value: 0.0031970123173881777 and parameters: {'n_estimators': 498, 'max_depth': 12, 'learning_rate': 0.2702542088628675, 'subsample': 0.8745252856749743, 'colsample_bytree': 0.965737147967342, 'gamma': 0.28595053372777207, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:20,245] Trial 69 finished with value: 0.0031745427952387367 and parameters: {'n_estimators': 472, 'max_depth': 11, 'learning_rate': 0.23300916170955843, 'subsample': 0.9539912451331064, 'colsample_bytree': 0.9901928447691949, 'gamma': 0.09850248373521983, 'min_child_weight': 9}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:20,939] Trial 70 finished with value: 0.0031581059304740225 and parameters: {'n_estimators': 340, 'max_depth': 9, 'learning_rate': 0.2637845134850469, 'subsample': 0.9356829292733385, 'colsample_bytree': 0.9996073181687836, 'gamma': 0.01715244281794557, 'min_child_weight': 8}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:21,743] Trial 71 finished with value: 0.003157816393539323 and parameters: {'n_estimators': 393, 'max_depth': 11, 'learning_rate': 0.2487108921531483, 'subsample': 0.8991087627575818, 'colsample_bytree': 0.9674051943084939, 'gamma': 0.0165392256195649, 'min_child_weight': 5}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:22,523] Trial 72 finished with value: 0.0031621292171279754 and parameters: {'n_estimators': 419, 'max_depth': 10, 'learning_rate': 0.2864467594198634, 'subsample': 0.9214500154242099, 'colsample_bytree': 0.944949557373281, 'gamma': 0.040989555364050655, 'min_child_weight': 6}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:23,229] Trial 73 finished with value: 0.0031581753470267242 and parameters: {'n_estimators': 361, 'max_depth': 12, 'learning_rate': 0.27651560146554205, 'subsample': 0.962846467876957, 'colsample_bytree': 0.9838155789763504, 'gamma': 0.026124920144788358, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:23,841] Trial 74 finished with value: 0.0031682890713126753 and parameters: {'n_estimators': 300, 'max_depth': 11, 'learning_rate': 0.24073522310432183, 'subsample': 0.9480097623668154, 'colsample_bytree': 0.9583709516158745, 'gamma': 0.0703010113577047, 'min_child_weight': 6}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:24,660] Trial 75 finished with value: 0.003166457311922963 and parameters: {'n_estimators': 454, 'max_depth': 13, 'learning_rate': 0.262836816471054, 'subsample': 0.9771628367795552, 'colsample_bytree': 0.9060499019218803, 'gamma': 0.04797431983546562, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:25,345] Trial 76 finished with value: 0.003166452167402672 and parameters: {'n_estimators': 325, 'max_depth': 8, 'learning_rate': 0.2553804357541214, 'subsample': 0.8588072310378577, 'colsample_bytree': 0.9187174317370734, 'gamma': 0.031248139690884996, 'min_child_weight': 5}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:26,194] Trial 77 finished with value: 0.0031572784618450365 and parameters: {'n_estimators': 434, 'max_depth': 11, 'learning_rate': 0.22933571541878406, 'subsample': 0.9931559886712568, 'colsample_bytree': 0.9743236211628796, 'gamma': 0.012848541388463336, 'min_child_weight': 6}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:26,741] Trial 78 finished with value: 0.0031720627403132107 and parameters: {'n_estimators': 265, 'max_depth': 10, 'learning_rate': 0.2910313670478364, 'subsample': 0.9144882506325197, 'colsample_bytree': 0.9886494209038297, 'gamma': 0.08229040107151495, 'min_child_weight': 6}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:27,410] Trial 79 finished with value: 0.0031679213863942813 and parameters: {'n_estimators': 346, 'max_depth': 9, 'learning_rate': 0.2787761921195761, 'subsample': 0.9592608247751426, 'colsample_bytree': 0.8676834665800208, 'gamma': 0.04000702861227416, 'min_child_weight': 8}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:28,285] Trial 80 finished with value: 0.0031768000310481857 and parameters: {'n_estimators': 479, 'max_depth': 12, 'learning_rate': 0.26858374099238885, 'subsample': 0.8419588943303788, 'colsample_bytree': 0.9421059563467375, 'gamma': 0.11047915956867527, 'min_child_weight': 7}. Best is trial 65 with value: 0.0031559753141934023.
# [I 2025-10-17 09:53:29,050] Trial 81 finished with value: 0.00315569708140462 and parameters: {'n_estimators': 400, 'max_depth': 11, 'learning_rate': 0.28000855581860873, 'subsample': 0.9727474214174959, 'colsample_bytree': 0.9545394471098659, 'gamma': 0.02013399225486456, 'min_child_weight': 5}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:33,665] Trial 82 finished with value: 0.0035684937026566627 and parameters: {'n_estimators': 372, 'max_depth': 11, 'learning_rate': 0.15460029168601142, 'subsample': 0.9295685427143744, 'colsample_bytree': 0.966878057284238, 'gamma': 0.00025962068234842636, 'min_child_weight': 5}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:34,419] Trial 83 finished with value: 0.0031567071102804817 and parameters: {'n_estimators': 388, 'max_depth': 10, 'learning_rate': 0.25284191334976364, 'subsample': 0.9731103100228718, 'colsample_bytree': 0.9543799628236544, 'gamma': 0.023222370398064907, 'min_child_weight': 4}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:35,144] Trial 84 finished with value: 0.0031675031799832136 and parameters: {'n_estimators': 387, 'max_depth': 10, 'learning_rate': 0.24843773789011725, 'subsample': 0.9662388859726193, 'colsample_bytree': 0.9354040658404772, 'gamma': 0.0581765631273346, 'min_child_weight': 4}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:35,942] Trial 85 finished with value: 0.0031583958356962674 and parameters: {'n_estimators': 415, 'max_depth': 10, 'learning_rate': 0.2814671026843741, 'subsample': 0.946195017931874, 'colsample_bytree': 0.9541037166945991, 'gamma': 0.014426876037884834, 'min_child_weight': 5}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:36,671] Trial 86 finished with value: 0.00316587837776959 and parameters: {'n_estimators': 402, 'max_depth': 9, 'learning_rate': 0.29942184102193653, 'subsample': 0.990110208536469, 'colsample_bytree': 0.9208001823107052, 'gamma': 0.03574179914623635, 'min_child_weight': 4}. Best is trial 81 with value: 0.00315569708140462.
# [I 2025-10-17 09:53:37,899] Trial 87 finished with value: 0.003154455567084791 and parameters: {'n_estimators': 429, 'max_depth': 12, 'learning_rate': 0.07161611988704197, 'subsample': 0.8924934578472358, 'colsample_bytree': 0.9693470153707967, 'gamma': 0.025931794102720077, 'min_child_weight': 3}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:39,156] Trial 88 finished with value: 0.0031670327132807983 and parameters: {'n_estimators': 428, 'max_depth': 12, 'learning_rate': 0.05212434390464821, 'subsample': 0.878519703234736, 'colsample_bytree': 0.993606318134836, 'gamma': 0.07057979128596088, 'min_child_weight': 3}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:40,294] Trial 89 finished with value: 0.0031622563213331662 and parameters: {'n_estimators': 450, 'max_depth': 12, 'learning_rate': 0.07448521573274722, 'subsample': 0.8977872287516361, 'colsample_bytree': 0.9723926788522366, 'gamma': 0.0511386563639369, 'min_child_weight': 4}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:41,288] Trial 90 finished with value: 0.00319380519926457 and parameters: {'n_estimators': 409, 'max_depth': 13, 'learning_rate': 0.11082021361202674, 'subsample': 0.9359659352370564, 'colsample_bytree': 0.6026968479669175, 'gamma': 0.0891740203820765, 'min_child_weight': 4}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:42,077] Trial 91 finished with value: 0.0031570584323397685 and parameters: {'n_estimators': 393, 'max_depth': 11, 'learning_rate': 0.2595998644929094, 'subsample': 0.8915869404204437, 'colsample_bytree': 0.959302639941739, 'gamma': 0.02278708346733135, 'min_child_weight': 5}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:45,435] Trial 92 finished with value: 0.0031575599733836813 and parameters: {'n_estimators': 460, 'max_depth': 12, 'learning_rate': 0.020117070299388508, 'subsample': 0.9147265115748439, 'colsample_bytree': 0.9828695222871782, 'gamma': 0.009892218822431366, 'min_child_weight': 3}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:46,367] Trial 93 finished with value: 0.0031576491153745357 and parameters: {'n_estimators': 444, 'max_depth': 11, 'learning_rate': 0.14378766683665314, 'subsample': 0.9551388308246281, 'colsample_bytree': 0.9466500217162045, 'gamma': 0.03387519163838909, 'min_child_weight': 5}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:47,115] Trial 94 finished with value: 0.0031566127702098152 and parameters: {'n_estimators': 375, 'max_depth': 10, 'learning_rate': 0.26516139045046916, 'subsample': 0.9259851240393692, 'colsample_bytree': 0.9661140419334274, 'gamma': 0.02178062148907711, 'min_child_weight': 6}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:47,832] Trial 95 finished with value: 0.003157218035557611 and parameters: {'n_estimators': 359, 'max_depth': 10, 'learning_rate': 0.2698148197000728, 'subsample': 0.9238158817667004, 'colsample_bytree': 0.9703586903469609, 'gamma': 0.025108399360375566, 'min_child_weight': 5}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:48,661] Trial 96 finished with value: 0.003164061340299958 and parameters: {'n_estimators': 376, 'max_depth': 11, 'learning_rate': 0.12771063983998188, 'subsample': 0.9731236558967781, 'colsample_bytree': 0.9901954571503713, 'gamma': 0.05356456074877878, 'min_child_weight': 3}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:49,455] Trial 97 finished with value: 0.003161863510122521 and parameters: {'n_estimators': 422, 'max_depth': 11, 'learning_rate': 0.28643904127537545, 'subsample': 0.9085414376524595, 'colsample_bytree': 0.9553315709686355, 'gamma': 0.038676814867366016, 'min_child_weight': 6}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:50,367] Trial 98 finished with value: 0.003166496834557838 and parameters: {'n_estimators': 385, 'max_depth': 10, 'learning_rate': 0.097698554114936, 'subsample': 0.9343172237297661, 'colsample_bytree': 0.9833450193404545, 'gamma': 0.063372796256597, 'min_child_weight': 4}. Best is trial 87 with value: 0.003154455567084791.
# [I 2025-10-17 09:53:51,217] Trial 99 finished with value: 0.003190326400303393 and parameters: {'n_estimators': 353, 'max_depth': 12, 'learning_rate': 0.26627183365622464, 'subsample': 0.8651833623554032, 'colsample_bytree': 0.928446162396545, 'gamma': 0.006668505623969978, 'min_child_weight': 4}. Best is trial 87 with value: 0.003154455567084791.
# Best trial:
#   MSE: 0.003154455567084791
#   Params:
#     n_estimators: 429
#     max_depth: 12
#     learning_rate: 0.07161611988704197
#     subsample: 0.8924934578472358
#     colsample_bytree: 0.9693470153707967
#     gamma: 0.025931794102720077
#     min_child_weight: 3
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9693470153707967, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.025931794102720077, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07161611988704197,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=12, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=429, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
optimized_pred = optimized_xgb.predict(X_test)
optimized_metrics = evalute_metrics(y_test,  optimized_pred) # 評価
display(optimized_metrics)
# Out:
#         MSE       MAE        R2
# 0  0.003155  0.043575  0.885726

# %%
def plot_residual_analysis(y_test, optimized_pred, figsize=(16, 12)):

    residuals = y_test - optimized_pred
    
    # 統計量の計算
    rmse = np.sqrt(np.mean(residuals**2))
    mae = np.mean(np.abs(residuals))
    r2 = 1 - (np.sum(residuals**2) / np.sum((y_test - np.mean(y_test))**2))
    
    # 2x2のサブプロット作成
    fig, axes = plt.subplots(2, 2, figsize=figsize)
    
    # ========================================
    # 1. 実際値 vs 予測値（左上）
    # ========================================
    ax1 = axes[0, 0]
    ax1.scatter(y_test, optimized_pred, alpha=0.5, s=30, edgecolors='k', linewidths=0.5)
    
    # 完全予測ライン（y=x）
    min_val = min(y_test.min(), optimized_pred.min())
    max_val = max(y_test.max(), optimized_pred.max())
    ax1.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Perfect Prediction')
    
    ax1.set_xlabel('Actual Accident Risk', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Predicted Accident Risk', fontsize=12, fontweight='bold')
    ax1.set_title('Actual vs Predicted Values', fontsize=14, fontweight='bold')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 統計情報をテキストで表示
    textstr = f'RMSE: {rmse:.5f}\nMAE: {mae:.5f}\nR²: {r2:.5f}'
    ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=11,
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    # ========================================
    # 2. 残差プロット（右上）
    # ========================================
    ax2 = axes[0, 1]
    ax2.scatter(optimized_pred, residuals, alpha=0.5, s=30, edgecolors='k', linewidths=0.5)
    ax2.axhline(y=0, color='r', linestyle='--', lw=2, label='Zero Residual')
    
    ax2.set_xlabel('Predicted Accident Risk', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Residuals (Actual - Predicted)', fontsize=12, fontweight='bold')
    ax2.set_title('Residual Plot', fontsize=14, fontweight='bold')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    # 残差の範囲を表示
    std_residual = np.std(residuals)
    ax2.axhline(y=2*std_residual, color='orange', linestyle=':', alpha=0.7, label='±2σ')
    ax2.axhline(y=-2*std_residual, color='orange', linestyle=':', alpha=0.7)
    
    # ========================================
    # 3. 残差のヒストグラム（左下）
    # ========================================
    ax3 = axes[1, 0]
    ax3.hist(residuals, bins=50, edgecolor='black', alpha=0.7, color='skyblue')
    ax3.axvline(x=0, color='r', linestyle='--', lw=2, label='Zero')
    ax3.axvline(x=np.mean(residuals), color='green', linestyle='-', lw=2, 
                label=f'Mean: {np.mean(residuals):.5f}')
    
    ax3.set_xlabel('Residuals', fontsize=12, fontweight='bold')
    ax3.set_ylabel('Frequency', fontsize=12, fontweight='bold')
    ax3.set_title('Distribution of Residuals', fontsize=14, fontweight='bold')
    ax3.legend()
    ax3.grid(True, alpha=0.3, axis='y')
    
    # ========================================
    # 4. Q-Qプロット（右下）
    # ========================================
    ax4 = axes[1, 1]
    stats.probplot(residuals, dist="norm", plot=ax4)
    ax4.set_title('Q-Q Plot (Normality Check)', fontsize=14, fontweight='bold')
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # ========================================
    # 統計サマリーを出力
    # ========================================
    print("=" * 60)
    print("残差分析サマリー")
    print("=" * 60)
    print(f"サンプル数: {len(y_test)}")
    print(f"\n【評価指標】")
    print(f"RMSE (Root Mean Squared Error): {rmse:.6f}")
    print(f"MAE  (Mean Absolute Error):     {mae:.6f}")
    print(f"R²   (Coefficient of Determination): {r2:.6f}")
    print(f"\n【残差統計】")
    print(f"残差の平均:   {np.mean(residuals):.6f}")
    print(f"残差の標準偏差: {np.std(residuals):.6f}")
    print(f"残差の最小値: {np.min(residuals):.6f}")
    print(f"残差の最大値: {np.max(residuals):.6f}")
    print(f"\n【外れ値検出】")
    outliers = np.abs(residuals) > 2 * std_residual
    print(f"±2σを超える外れ値の数: {np.sum(outliers)} ({np.sum(outliers)/len(residuals)*100:.2f}%)")
    print("=" * 60)
    
    return residuals


def plot_residual_by_range(y_test, optimized_pred, n_bins=10, figsize=(14, 6)):
    """
    予測値の範囲別に残差を分析
    
    Parameters:
    -----------
    y_test : array-like
        実際の事故リスク値
    optimized_pred : array-like
        予測された事故リスク値
    n_bins : int
        ビンの数
    """
    residuals = y_test - optimized_pred
    
    # 予測値の範囲でビン分割
    bins = np.linspace(optimized_pred.min(), optimized_pred.max(), n_bins + 1)
    bin_indices = np.digitize(optimized_pred, bins)
    
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    # 左: ビン別の平均残差
    ax1 = axes[0]
    mean_residuals = []
    bin_centers = []
    
    for i in range(1, n_bins + 1):
        mask = bin_indices == i
        if np.sum(mask) > 0:
            mean_residuals.append(np.mean(residuals[mask]))
            bin_centers.append((bins[i-1] + bins[i]) / 2)
    
    ax1.bar(bin_centers, mean_residuals, width=(bins[1]-bins[0])*0.8, 
            edgecolor='black', alpha=0.7)
    ax1.axhline(y=0, color='r', linestyle='--', lw=2)
    ax1.set_xlabel('Predicted Accident Risk (Binned)', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Mean Residual', fontsize=12, fontweight='bold')
    ax1.set_title('Mean Residual by Prediction Range', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3, axis='y')
    
    # 右: ビン別の残差の分散
    ax2 = axes[1]
    std_residuals = []
    
    for i in range(1, n_bins + 1):
        mask = bin_indices == i
        if np.sum(mask) > 0:
            std_residuals.append(np.std(residuals[mask]))
    
    ax2.bar(bin_centers, std_residuals, width=(bins[1]-bins[0])*0.8,
            edgecolor='black', alpha=0.7, color='orange')
    ax2.set_xlabel('Predicted Accident Risk (Binned)', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Std Dev of Residuals', fontsize=12, fontweight='bold')
    ax2.set_title('Residual Variance by Prediction Range', fontsize=14, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.show()


def plot_error_distribution(y_test, optimized_pred, figsize=(14, 5)):
    """
    誤差の詳細な分布分析
    """
    residuals = y_test - optimized_pred
    abs_errors = np.abs(residuals)
    
    fig, axes = plt.subplots(1, 3, figsize=figsize)
    
    # 1. 絶対誤差の累積分布
    ax1 = axes[0]
    sorted_errors = np.sort(abs_errors)
    cumulative = np.arange(1, len(sorted_errors) + 1) / len(sorted_errors) * 100
    ax1.plot(sorted_errors, cumulative, linewidth=2)
    ax1.set_xlabel('Absolute Error', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Cumulative Percentage (%)', fontsize=12, fontweight='bold')
    ax1.set_title('Cumulative Error Distribution', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3)
    
    # パーセンタイルを表示
    percentiles = [50, 75, 90, 95]
    for p in percentiles:
        val = np.percentile(abs_errors, p)
        ax1.axvline(x=val, linestyle='--', alpha=0.5, 
                   label=f'{p}%ile: {val:.4f}')
    ax1.legend(fontsize=9)
    
    # 2. 誤差率のヒストグラム
    ax2 = axes[1]
    error_percent = (residuals / y_test) * 100
    error_percent = error_percent[~np.isnan(error_percent) & ~np.isinf(error_percent)]
    ax2.hist(error_percent, bins=50, edgecolor='black', alpha=0.7, color='coral')
    ax2.axvline(x=0, color='r', linestyle='--', lw=2)
    ax2.set_xlabel('Error Percentage (%)', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Frequency', fontsize=12, fontweight='bold')
    ax2.set_title('Relative Error Distribution', fontsize=14, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    
    # 3. 誤差の箱ひげ図
    ax3 = axes[2]
    bp = ax3.boxplot([residuals], labels=['Residuals'], patch_artist=True)
    bp['boxes'][0].set_facecolor('lightblue')
    ax3.axhline(y=0, color='r', linestyle='--', lw=2)
    ax3.set_ylabel('Residuals', fontsize=12, fontweight='bold')
    ax3.set_title('Residual Box Plot', fontsize=14, fontweight='bold')
    ax3.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.show()
    
    print("\n誤差パーセンタイル:")
    for p in [25, 50, 75, 90, 95, 99]:
        print(f"{p}%: {np.percentile(abs_errors, p):.6f}")


# ========================================
# 使用例
# ========================================
if __name__ == "__main__":
    print("=" * 60)
    print("残差プロット分析ツール")
    print("=" * 60)
    print("\n使い方:")
    print("1. 基本的な残差分析:")
    print("   residuals = plot_residual_analysis(y_test, optimized_pred)")
    print("\n2. 予測範囲別の分析:")
    print("   plot_residual_by_range(y_test, optimized_pred)")
    print("\n3. 誤差分布の詳細分析:")
    print("   plot_error_distribution(y_test, optimized_pred)")
    print("\n必要なデータ:")
    print("  - y_test: 実際の事故リスク値（正解データ）")
    print("  - optimized_pred: 予測された事故リスク値")
    print("=" * 60)
# Out:
# ============================================================
# 残差プロット分析ツール
# ============================================================
#
# 使い方:
# 1. 基本的な残差分析:
#    residuals = plot_residual_analysis(y_test, optimized_pred)
#
# 2. 予測範囲別の分析:
#    plot_residual_by_range(y_test, optimized_pred)
#
# 3. 誤差分布の詳細分析:
#    plot_error_distribution(y_test, optimized_pred)
#
# 必要なデータ:
#   - y_test: 実際の事故リスク値（正解データ）
#   - optimized_pred: 予測された事故リスク値
# ============================================================

# %%
# 1. 総合分析（最も重要）
print("=" * 60)
print("1. 総合残差分析")
print("=" * 60)
residuals = plot_residual_analysis(y_test, optimized_pred)

# 2. 範囲別分析
print("\n" + "=" * 60)
print("2. 予測範囲別の残差分析")
print("=" * 60)
plot_residual_by_range(y_test, optimized_pred, n_bins=10)

# 3. 誤差分布分析
print("\n" + "=" * 60)
print("3. 誤差分布の詳細分析")
print("=" * 60)
plot_error_distribution(y_test, optimized_pred)
# Out:
# ============================================================
# 1. 総合残差分析
# ============================================================
# ============================================================
# 残差分析サマリー
# ============================================================
# サンプル数: 103551
#
# 【評価指標】
# RMSE (Root Mean Squared Error): 0.056173
# MAE  (Mean Absolute Error):     0.043575
# R²   (Coefficient of Determination): 0.885726
#
# 【残差統計】
# 残差の平均:   -0.000191
# 残差の標準偏差: 0.056172
# 残差の最小値: -0.379709
# 残差の最大値: 0.885070
#
# 【外れ値検出】
# ±2σを超える外れ値の数: 4214 (4.07%)
# ============================================================
#
# ============================================================
# 2. 予測範囲別の残差分析
# ============================================================
# ============================================================
# 3. 誤差分布の詳細分析
# ============================================================
# /var/folders/cn/wb1xxprs41l8cbm22w4cs68w0000gn/T/ipykernel_14313/4210867147.py:203: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax3.boxplot([residuals], labels=['Residuals'], patch_artist=True)
# 誤差パーセンタイル:
# 25%: 0.017086
# 50%: 0.036101
# 75%: 0.061867
# 90%: 0.089075
# 95%: 0.107068
# 99%: 0.157001

# %%
file_path = "model/xgboost_model/xgboost_model_1.json"

if os.path.exists(file_path):
     print(f"ファイルが既にあります{file_path}.")
else:
    # XGBoost の Booster オブジェクトを取得して保存
     optimized_xgb.get_booster().save_model(file_path)
     print(f"ファイルを保存しました: {file_path}")
# Out:
# ファイルを保存しました: model/xgboost_model/xgboost_model_1.json

# %% [markdown]
# ## 提出準備

# %%
# テストデータ予測
predict_y = optimized_xgb.predict(predict_X)
predict_df = pd.DataFrame(predict_y, columns=['accident_risk'])
submission = pd.concat([predict['id'], predict_df], axis=1)

display(submission.head())
print(submission.isnull().sum())
# Out:
#        id  accident_risk
# 0  517754       0.299603
# 1  517755       0.122829
# 2  517756       0.180109
# 3  517757       0.310105
# 4  517758       0.404696
# id               0
# accident_risk    0
# dtype: int64

# %%
# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['accident_risk'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(submission['accident_risk'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
file_path = '../submit/xgboost/xgboost_model_3.csv'

if os.path.exists(file_path):
     print(f"ファイルが既にあります{file_path}.")
else:
    submission.to_csv(file_path, index=False)
    print(f"ファイルを保存しました: {file_path}")
# Out:
# ファイルが既にあります../submit/xgboost/xgboost_model_3.csv.
